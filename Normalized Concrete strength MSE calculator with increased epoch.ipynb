# %% [markdown]
# # Made By : Sayandeep Dey

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
# Out:
# 2024-01-21 19:34:29.663166: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-21 19:34:29.700083: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-21 19:34:29.700123: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-21 19:34:29.701457: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-21 19:34:29.707152: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ...

# %% [markdown]
# ## Downloading database

# %%
con_dat=pd.read_csv('https://cocl.us/concrete_data')
con_dat.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# ## Splitting the dataset into the predicted variable and the target variables

# %%
con_dat_col=con_dat.columns
predictors=con_dat[con_dat_col[con_dat_col!='Strength']]
target=con_dat['Strength']
predictors_norm=(predictors-predictors.mean())/predictors.std() #normalizing the predictors
n_cols=predictors_norm.shape[1] #number of predictors

# %% [markdown]
# ## Building the NN model

# %%
def regression_model():
		model=Sequential()
		model.add(Dense(10,activation='relu',input_shape=(n_cols,)))
		model.add(Dense(10,activation='relu'))
		model.add(Dense(1))
		model.compile(optimizer='adam',loss='mean_squared_error')
		return model

# %% [markdown]
# ## Testing and Training

# %% [markdown]
# Building the model

# %%
model=regression_model()

# %% [markdown]
# Traing and Testing the model with 50 epochs, 50 times to make a list of 50 mean squared errors.

# %%
mse_list=np.array([])
for i in range(50):
	print(f"Test {i+1} is starting:\n")
	X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.30, random_state=42)
	model.fit(X_train,y_train,epochs=100,verbose=2)
	y_hat=model.predict(X_test)
	mse=mean_squared_error(y_test,y_hat)
	mse_list=np.append(mse_list,mse)
# Out:
# Test 1 is starting:
#
# Epoch 1/100
# 23/23 - 1s - loss: 1592.7441 - 578ms/epoch - 25ms/step
# Epoch 2/100
# 23/23 - 0s - loss: 1572.9628 - 61ms/epoch - 3ms/step
# Epoch 3/100
# 23/23 - 0s - loss: 1553.9612 - 61ms/epoch - 3ms/step
# Epoch 4/100
# 23/23 - 0s - loss: 1532.1556 - 61ms/epoch - 3ms/step
# Epoch 5/100
# 23/23 - 0s - loss: 1505.5371 - 52ms/epoch - 2ms/step
# Epoch 6/100
# 23/23 - 0s - loss: 1472.3531 - 47ms/epoch - 2ms/step
# Epoch 7/100
# 23/23 - 0s - loss: 1430.3737 - 52ms/epoch - 2ms/step
# Epoch 8/100
# 23/23 - 0s - loss: 1379.2990 - 50ms/epoch - 2ms/step
# Epoch 9/100
# 23/23 - 0s - loss: 1316.2839 - 51ms/epoch - 2ms/step
# Epoch 10/100
# 23/23 - 0s - loss: 1242.8422 - 50ms/epoch - 2ms/step
# Epoch 11/100
# 23/23 - 0s - loss: 1155.9360 - 51ms/epoch - 2ms/step
# Epoch 12/100
# 23/23 - 0s - loss: 1058.0674 - 47ms/epoch - 2ms/step
# Epoch 13/100
# 23/23 - 0s - loss: 950.8826 - 50ms/epoch - 2ms/step
# Epoch 14/100
# 23/23 - 0s - loss: 834.6907 - 51ms/epoch - 2ms/step
# ...

# %% [markdown]
# Displaying the values of mean squared errors, it's mean and standard deviation.

# %%
print('The list of the mean squared errors is',mse_list)
print('The mean of the mean squared errors is: ',mse_list.mean())
print('The standard deviation of the mean squared errors is: ',mse_list.std())
# Out:
# The list of the mean squared errors is [115.48721019  58.44428548  43.72082546  40.46872628  39.06823293
#   36.39129191  34.50687779  32.8178119   31.87438018  32.13915415
#   31.11086039  30.76236977  30.35566979  30.2745573   30.46307532
#   29.84588542  29.43123654  30.38653895  29.76537921  29.49907267
#   29.64917075  29.83016537  30.51767521  29.49336423  30.46436136
#   29.4759311   29.43451895  29.40211649  29.75955914  29.73499139
#   29.61748245  29.38811464  29.39694521  29.18215211  29.57862966
#   30.50671682  30.53271403  29.39768832  30.11094031  28.76265626
#   29.05081514  30.41521586  30.05001795  29.56109591  29.82275676
#   29.67129787  30.28695721  29.28149434  29.40400827  29.4237543 ]
# The mean of the mean squared errors is:  33.16033497982494
# The standard deviation of the mean squared errors is:  12.71763364000517

# %% [markdown]
# We see that avegage mean squared error has decreased from 43 to 33(from my observation) and the standard deviation has decreased from 13 to 12(from my observation). This means the average error is significantly less from before(part B) and the standard deviation is also less. This means the model is more accurate for predicting than before.
